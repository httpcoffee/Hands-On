# %%
import os

# %%
os.chdir("C:\\Users\\asus\\Desktop\\ML")

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Salaries.csv")

# %%
df
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df.head()
# Out:
#    rank discipline  phd  service   sex  salary
# 0  Prof          B   56       49  Male  186960
# 1  Prof          A   12        6  Male   93000
# 2  Prof          A   23       20  Male  110515
# 3  Prof          A   40       31  Male  131205
# 4  Prof          B   20       18  Male  104800

# %%
df.head(10)
# Out:
#         rank discipline  phd  service   sex  salary
# 0       Prof          B   56       49  Male  186960
# 1       Prof          A   12        6  Male   93000
# 2       Prof          A   23       20  Male  110515
# 3       Prof          A   40       31  Male  131205
# 4       Prof          B   20       18  Male  104800
# 5       Prof          A   20       20  Male  122400
# 6  AssocProf          A   20       17  Male   81285
# 7       Prof          A   18       18  Male  126300
# 8       Prof          A   29       19  Male   94350
# 9       Prof          A   51       51  Male   57800

# %%
df.head(20)
# Out:
#          rank discipline  phd  service   sex  salary
# 0        Prof          B   56       49  Male  186960
# 1        Prof          A   12        6  Male   93000
# 2        Prof          A   23       20  Male  110515
# 3        Prof          A   40       31  Male  131205
# 4        Prof          B   20       18  Male  104800
# 5        Prof          A   20       20  Male  122400
# 6   AssocProf          A   20       17  Male   81285
# 7        Prof          A   18       18  Male  126300
# 8        Prof          A   29       19  Male   94350
# 9        Prof          A   51       51  Male   57800
# 10       Prof          B   39       33  Male  128250
# 11       Prof          B   23       23  Male  134778
# 12   AsstProf          B    1        0  Male   88000
# 13       Prof          B   35       33  Male  162200
# 14       Prof          B   25       19  Male  153750
# 15       Prof          B   17        3  Male  150480
# 16   AsstProf          B    8        3  Male   75044
# ...

# %%
df.head(50)
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# 10       Prof          B   39       33    Male  128250
# 11       Prof          B   23       23    Male  134778
# 12   AsstProf          B    1        0    Male   88000
# 13       Prof          B   35       33    Male  162200
# 14       Prof          B   25       19    Male  153750
# 15       Prof          B   17        3    Male  150480
# ...

# %%
df.dtypes
# Out:
# rank          object
# discipline    object
# phd            int64
# service        int64
# sex           object
# salary         int64
# dtype: object

# %%
df['salary'].dtype
# Out:
# dtype('int64')

# %%
df.ndim
# Out:
# 2

# %%
df.size
# Out:
# 468

# %%
df.shape
# Out:
# (78, 6)

# %%
df.values
# Out:
# array([['Prof', 'B', 56, 49, 'Male', 186960],
#        ['Prof', 'A', 12, 6, 'Male', 93000],
#        ['Prof', 'A', 23, 20, 'Male', 110515],
#        ['Prof', 'A', 40, 31, 'Male', 131205],
#        ['Prof', 'B', 20, 18, 'Male', 104800],
#        ['Prof', 'A', 20, 20, 'Male', 122400],
#        ['AssocProf', 'A', 20, 17, 'Male', 81285],
#        ['Prof', 'A', 18, 18, 'Male', 126300],
#        ['Prof', 'A', 29, 19, 'Male', 94350],
#        ['Prof', 'A', 51, 51, 'Male', 57800],
#        ['Prof', 'B', 39, 33, 'Male', 128250],
#        ['Prof', 'B', 23, 23, 'Male', 134778],
#        ['AsstProf', 'B', 1, 0, 'Male', 88000],
#        ['Prof', 'B', 35, 33, 'Male', 162200],
#        ['Prof', 'B', 25, 19, 'Male', 153750],
#        ['Prof', 'B', 17, 3, 'Male', 150480],
#        ['AsstProf', 'B', 8, 3, 'Male', 75044],
#        ['AsstProf', 'B', 4, 0, 'Male', 92000],
#        ['Prof', 'A', 19, 7, 'Male', 107300],
#        ['Prof', 'A', 29, 27, 'Male', 150500],
# ...

# %%
df.describe()
# Out:
#              phd    service         salary
# count  78.000000  78.000000      78.000000
# mean   19.705128  15.051282  108023.782051
# std    12.498425  12.139768   28293.661022
# min     1.000000   0.000000   57800.000000
# 25%    10.250000   5.250000   88612.500000
# 50%    18.500000  14.500000  104671.000000
# 75%    27.750000  20.750000  126774.750000
# max    56.000000  51.000000  186960.000000

# %%
df['salary'].max()
# Out:
# 186960

# %%
df.sample(5)
# Out:
#          rank discipline  phd  service     sex  salary
# 47  AssocProf          B   11       11  Female  103613
# 61  AssocProf          B   13       10  Female  103750
# 18       Prof          A   19        7    Male  107300
# 67       Prof          A   17       11  Female   90450
# 75       Prof          B   17       17  Female  124312

# %%
df.sample(5)
# Out:
#     rank discipline  phd  service     sex  salary
# 2   Prof          A   23       20    Male  110515
# 44  Prof          B   23       19  Female  151768
# 33  Prof          B   18       18    Male  120000
# 40  Prof          A   39       36  Female  137000
# 18  Prof          A   19        7    Male  107300

# %%
df1= df.dropna()

# %%
df1
# Out:
#          rank discipline  phd  service     sex  salary
# 0        Prof          B   56       49    Male  186960
# 1        Prof          A   12        6    Male   93000
# 2        Prof          A   23       20    Male  110515
# 3        Prof          A   40       31    Male  131205
# 4        Prof          B   20       18    Male  104800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [78 rows x 6 columns]

# %%
df1.size
# Out:
# 468

# %%
df1= df.head(50)
df1.mean()
# Out:
# C:\Users\asus\AppData\Local\Temp\ipykernel_16116\1870074959.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df1.mean()
# phd            21.52
# service        17.60
# salary     113789.14
# dtype: float64

# %% [markdown]
# df["salary"].describe()

# %%
df["salary"].describe()
# Out:
# count        78.000000
# mean     108023.782051
# std       28293.661022
# min       57800.000000
# 25%       88612.500000
# 50%      104671.000000
# 75%      126774.750000
# max      186960.000000
# Name: salary, dtype: float64

# %%
df["salary"].count()
# Out:
# 78

# %%
df["salary"].mean()
# Out:
# 108023.78205128205

# %%
df[['salary','phd']].mean()
# Out:
# salary    108023.782051
# phd           19.705128
# dtype: float64

# %%
df_rank=df.groupby(['rank'])

# %%
df_rank.count( )
# Out:
#            discipline  phd  service  sex  salary
# rank
# AssocProf          13   13       13   13      13
# AsstProf           19   19       19   19      19
# Prof               46   46       46   46      46

# %%
df.groupby(['rank']).mean()
# Out:
#                  phd    service         salary
# rank
# AssocProf  15.076923  11.307692   91786.230769
# AsstProf    5.052632   2.210526   81362.789474
# Prof       27.065217  21.413043  123624.804348

# %%
df.groupby(['rank'], sort=False)[['salary']].mean()
# Out:
#                   salary
# rank
# Prof       123624.804348
# AssocProf   91786.230769
# AsstProf    81362.789474

# %%
df.groupby(['rank'], sort=True)[['salary']].mean()
# Out:
#                   salary
# rank
# AssocProf   91786.230769
# AsstProf    81362.789474
# Prof       123624.804348

# %%
df['salary']>120000
# Out:
# 0      True
# 1     False
# 2     False
# 3      True
# 4     False
#       ...
# 73    False
# 74    False
# 75     True
# 76    False
# 77    False
# Name: salary, Length: 78, dtype: bool

# %%
df[df['salary']>120000]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 3   Prof          A   40       31    Male  131205
# 5   Prof          A   20       20    Male  122400
# 7   Prof          A   18       18    Male  126300
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 19  Prof          A   29       27    Male  150500
# 26  Prof          A   38       19    Male  148750
# 27  Prof          A   45       43    Male  155865
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 40  Prof          A   39       36  Female  137000
# ...

# %%
df[(df['salary']>120000) & (df['discipline']=='B')]
# Out:
#     rank discipline  phd  service     sex  salary
# 0   Prof          B   56       49    Male  186960
# 10  Prof          B   39       33    Male  128250
# 11  Prof          B   23       23    Male  134778
# 13  Prof          B   35       33    Male  162200
# 14  Prof          B   25       19    Male  153750
# 15  Prof          B   17        3    Male  150480
# 29  Prof          B   21       20    Male  123683
# 31  Prof          B   22       21    Male  155750
# 35  Prof          B   28       23    Male  126933
# 36  Prof          B   45       45    Male  146856
# 39  Prof          B   18       18  Female  129000
# 44  Prof          B   23       19  Female  151768
# 45  Prof          B   25       25  Female  140096
# 49  Prof          B   17       18  Female  122960
# 51  Prof          B   20       14  Female  127512
# 58  Prof          B   36       26  Female  144651
# 72  Prof          B   24       15  Female  161101
# 75  Prof          B   17       17  Female  124312

# %%
df[10:20]
# Out:
#         rank discipline  phd  service   sex  salary
# 10      Prof          B   39       33  Male  128250
# 11      Prof          B   23       23  Male  134778
# 12  AsstProf          B    1        0  Male   88000
# 13      Prof          B   35       33  Male  162200
# 14      Prof          B   25       19  Male  153750
# 15      Prof          B   17        3  Male  150480
# 16  AsstProf          B    8        3  Male   75044
# 17  AsstProf          B    4        0  Male   92000
# 18      Prof          A   19        7  Male  107300
# 19      Prof          A   29       27  Male  150500

# %%
df[5:]
# Out:
#          rank discipline  phd  service     sex  salary
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# ..        ...        ...  ...      ...     ...     ...
# 73       Prof          B   18       10  Female  105450
# 74  AssocProf          B   19        6  Female  104542
# 75       Prof          B   17       17  Female  124312
# 76       Prof          A   28       14  Female  109954
# 77       Prof          A   23       15  Female  109646
#
# [73 rows x 6 columns]

# %%
df[5:-10]
# Out:
#          rank discipline  phd  service     sex  salary
# 5        Prof          A   20       20    Male  122400
# 6   AssocProf          A   20       17    Male   81285
# 7        Prof          A   18       18    Male  126300
# 8        Prof          A   29       19    Male   94350
# 9        Prof          A   51       51    Male   57800
# ..        ...        ...  ...      ...     ...     ...
# 63       Prof          A   29       27  Female   91000
# 64  AssocProf          A   26       24  Female   73300
# 65       Prof          A   36       19  Female  117555
# 66   AsstProf          A    7        6  Female   63100
# 67       Prof          A   17       11  Female   90450
#
# [63 rows x 6 columns]

# %%
df_sub=df.loc[10:20 , ['rank', 'salary', 'sex']]
df_sub
# Out:
#         rank  salary   sex
# 10      Prof  128250  Male
# 11      Prof  134778  Male
# 12  AsstProf   88000  Male
# 13      Prof  162200  Male
# 14      Prof  153750  Male
# 15      Prof  150480  Male
# 16  AsstProf   75044  Male
# 17  AsstProf   92000  Male
# 18      Prof  107300  Male
# 19      Prof  150500  Male
# 20  AsstProf   92000  Male

# %%
df.iloc[0]
# Out:
# rank            Prof
# discipline         B
# phd               56
# service           49
# sex             Male
# salary        186960
# Name: 0, dtype: object

# %%
df.iloc[1:3, 0:2] #colon is used for range m:n, x:y means m to n rows and x to  y columns.
# Out:
#    rank discipline
# 1  Prof          A
# 2  Prof          A

# %%
df.iloc[[0,5],[1,3]] #comma is used for selecting particular rows or columns here 0th and 5th row and 1st and 3rd col.
# Out:
#   discipline  service
# 0          B       49
# 5          A       20

# %%
df.sort_values(by ='service' , inplace= True)

# %%
df
# Out:
#         rank discipline  phd  service     sex  salary
# 55  AsstProf          A    2        0  Female   72500
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# ..       ...        ...  ...      ...     ...     ...
# 40      Prof          A   39       36  Female  137000
# 27      Prof          A   45       43    Male  155865
# 36      Prof          B   45       45    Male  146856
# 0       Prof          B   56       49    Male  186960
# 9       Prof          A   51       51    Male   57800
#
# [78 rows x 6 columns]

# %%
df.sort_values(by = ['service','salary'] , ascending =[True, False] , inplace= True)

# %%
df
# Out:
#         rank discipline  phd  service     sex  salary
# 52      Prof          A   12        0  Female  105000
# 17  AsstProf          B    4        0    Male   92000
# 12  AsstProf          B    1        0    Male   88000
# 23  AsstProf          A    2        0    Male   85000
# 43  AsstProf          B    5        0  Female   77000
# ..       ...        ...  ...      ...     ...     ...
# 40      Prof          A   39       36  Female  137000
# 27      Prof          A   45       43    Male  155865
# 36      Prof          B   45       45    Male  146856
# 0       Prof          B   56       49    Male  186960
# 9       Prof          A   51       51    Male   57800
#
# [78 rows x 6 columns]

# %%
df.isnull().any()
# Out:
# rank          False
# discipline    False
# phd           False
# service       False
# sex           False
# salary        False
# dtype: bool

# %%
df[df.isnull().any(axis=1)]
# Out:
# Empty DataFrame
# Columns: [rank, discipline, phd, service, sex, salary]
# Index: []

# %%
df1 = pd.read_csv("flights.csv")

# %%
df1
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4       2013      1    1     554.0       -4.0     740.0       12.0      UA
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 160749  2013      9   30    2105.0       -1.0    2329.0      -25.0      UA
# 160750  2013      9   30    2121.0       21.0    2349.0      -25.0      DL
# 160751  2013      9   30    2140.0        0.0      10.0      -30.0      AA
# 160752  2013      9   30    2149.0       -7.0    2245.0      -23.0      UA
# 160753  2013      9   30    2233.0       80.0     112.0       42.0      UA
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
df1[df1.isnull().any(axis=1)]
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 330     2013      1    1    1807.0       29.0    2251.0        NaN      UA
# 403     2013      1    1       NaN        NaN       NaN        NaN      AA
# 404     2013      1    1       NaN        NaN       NaN        NaN      AA
# 855     2013      1    2    2145.0       16.0       NaN        NaN      UA
# 858     2013      1    2       NaN        NaN       NaN        NaN      AA
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 159681  2013      9   28    1214.0      -11.0    1801.0        NaN      AA
# 159854  2013      9   28       NaN        NaN       NaN        NaN      AA
# 159855  2013      9   28       NaN        NaN       NaN        NaN      US
# 160185  2013      9   29    1734.0       23.0    2159.0        NaN      UA
# 160286  2013      9   29       NaN        NaN       NaN        NaN      UA
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
df1.dropna(axis=1,how='all')
# Out:
#         year  month  day  dep_time  dep_delay  arr_time  arr_delay carrier  \
# 0       2013      1    1     517.0        2.0     830.0       11.0      UA
# 1       2013      1    1     533.0        4.0     850.0       20.0      UA
# 2       2013      1    1     542.0        2.0     923.0       33.0      AA
# 3       2013      1    1     554.0       -6.0     812.0      -25.0      DL
# 4       2013      1    1     554.0       -4.0     740.0       12.0      UA
# ...      ...    ...  ...       ...        ...       ...        ...     ...
# 160749  2013      9   30    2105.0       -1.0    2329.0      -25.0      UA
# 160750  2013      9   30    2121.0       21.0    2349.0      -25.0      DL
# 160751  2013      9   30    2140.0        0.0      10.0      -30.0      AA
# 160752  2013      9   30    2149.0       -7.0    2245.0      -23.0      UA
# 160753  2013      9   30    2233.0       80.0     112.0       42.0      UA
#
#        tailnum  flight origin dest  air_time  distance  hour  minute
# ...

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()

# %%
plt.scatter(df1.dep_time  , df1.arr_time)

# %%
plt.title('This is a flight departure chart')
# Out:
# Text(0.5, 1.0, 'This is a flight departure chart')

# %%
plt.scatter(df1.dep_time  , df1.arr_time, color='red')
plt.title('This is a flight departure chart')
plt.xlabel('departure')
plt.ylabel('arrival')
# Out:
# Text(0, 0.5, 'arrival')

# %%
plt.plot(df1.dep_time  , df1.arr_time, color='purple')
